# %% [raw]
# Level 1:
# Task 3: Geospatial Analysis
# 1. Visualize the locations of restaurants on a
# map using latitude and longitude
# information.
# 2. Analyze the distribution of restaurants
# across different cities or countries.
# 3. Determine if there is any correlation
# between the restaurant's location and its
# rating.

# %%
#1. Visualize the locations of restaurants on a map using latitude and longitude information.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = df.dropna(subset=['Latitude', 'Longitude'])  # Remove missing values
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Longitude'], y=df['Latitude'], alpha=0.5, color='blue')
plt.title("Restaurant Locations")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.show()

# %%
#2. Analyze the distribution of restaurants across different cities or countries.
import matplotlib.pyplot as plt
import seaborn as sns
city_counts = df['City'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=city_counts.index, y=city_counts.values, palette="coolwarm")
plt.title("Top 10 Cities with the Highest Number of Restaurants")
plt.xlabel("City")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=45)
plt.show()
country_counts = df['Country Code'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, palette="magma")
plt.title("Top 10 Countries with the Highest Number of Restaurants")
plt.xlabel("Country Code")
plt.ylabel("Number of Restaurants")
plt.show()
# Out:
# C:\Users\Sri vidhya\AppData\Local\Temp\ipykernel_36096\2416142562.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_counts.index, y=city_counts.values, palette="coolwarm")
# C:\Users\Sri vidhya\AppData\Local\Temp\ipykernel_36096\2416142562.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette="magma")

# %%
#3.Determine if there is any correlation between the restaurant's location and itsrating.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = df.dropna(subset=['Latitude', 'Longitude', 'Aggregate rating'])  
correlation_matrix = df[['Latitude', 'Longitude', 'Aggregate rating']].corr()
print("Correlation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Latitude'], y=df['Aggregate rating'], alpha=0.5)
plt.title("Latitude vs. Restaurant Ratings")
plt.xlabel("Latitude")
plt.ylabel("Aggregate Rating")
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Longitude'], y=df['Aggregate rating'], alpha=0.5)
plt.title("Longitude vs. Restaurant Ratings")
plt.xlabel("Longitude")
plt.ylabel("Aggregate Rating")
plt.show()
# Out:
# Correlation Matrix:
#                   Latitude  Longitude  Aggregate rating
# Latitude          1.000000   0.043207          0.000516
# Longitude         0.043207   1.000000         -0.116818
# Aggregate rating  0.000516  -0.116818          1.000000
